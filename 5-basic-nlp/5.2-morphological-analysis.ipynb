# %% [markdown]
# ### Morphological Analysis (w/ Spacy)
#
# Morphological Analysis is the process of analyzing the structure of words by breaking them down into their components, such as stems, prefixes, suffixes, and roots. It helps to understand the internal structure of words, including the derivation, inflection, and grammatical features.
#
# #### Common aspects of Morphological Analysis include:
#
# - Stemming: Reducing words to their root form (e.g., "running" → "run").
# - Lemmatization: Reducing words to their base or dictionary form (e.g., "better" → "good").
# - Inflection: Analyzing how words change form to express grammatical features like tense, number, gender, etc. (e.g., "dogs" → "dog" for singular).
# - Derivation: Understanding how new words are created from base words by adding prefixes or suffixes (e.g., "happy" → "unhappy").
#
# In short, Morphological Analysis involves understanding the structure of words and how they are formed from smaller units.
#
# #### Morphological Analysis Examples:
#
# - Stemming: "running" → "run"
# - Lemmatization: "better" → "good"
# - Inflection: "dogs" → "dog" (singular)
# - Derivation: "unhappy" → "happy" with prefix "un-"

# %% [markdown]
# ---

# %%
import pandas as pd
import spacy

pd.set_option("display.width", 200)  # Set the display width

nlp = spacy.load("en_core_web_sm")

corpus = [
    "John has 5 apples, but he gave 2 to his friend.",
    "The event will start at 7:30 PM, and we expect around 100 guests.",
    "I have read 3 books this month, and I'm planning to read 2 more before the end of the week.",
]

# word = "books"
# for token in doc:
#     print(f"{"Text":<10}: {token.text}")                          # books
#     print(f"{"Lemma":<10}:", token.lemma_)                        # book
#     print(f"{"PoS":<10}:", token.pos_)                            # NOUN
#     print(f"{"Tag":<10}:", token.tag_)  # Plural                  # NNS
#     print(f"{"Dependency":<10}:", token.dep_)                     # ROOT
#     print(f"{"Shape":<10}:", token.shape_)                        # xxxx
#     print(f"{"Is alpha":<10}:", token.is_alpha)                   # True
#     print(f"{"Is stop":<10}:", token.is_stop)                     # False
#     print(f"{"Morphology":<10}:", token.morph)                    # Number=Plur
#     print(f"{"Is plural":<10}: {'Number=Plur' in token.morph}")   # True

docs = []
for sentence in corpus:
    doc = nlp(sentence)
    for token in doc:
        res = {
            "word": token.text,
            "lemma_": token.lemma_,
            "pos_": token.pos_,
            "tag_": token.tag_,
            "dep_": token.dep_,
            "shape_": token.shape_,
            "is_alpha": token.is_alpha,
            "is_stop": token.is_stop,
            "morph": token.morph,
            "is_plural": "Number=Plur" in token.morph,
        }
        docs.append(res)


df = pd.DataFrame(docs)

print(df)
# Out:
#         word  lemma_   pos_  tag_      dep_ shape_  is_alpha  is_stop                                              morph  is_plural
# 0       John    John  PROPN   NNP     nsubj   Xxxx      True    False                                      (Number=Sing)      False
# 1        has    have   VERB   VBZ      ROOT    xxx      True     True  (Mood=Ind, Number=Sing, Person=3, Tense=Pres, ...      False
# 2          5       5    NUM    CD    nummod      d     False    False                                     (NumType=Card)      False
# 3     apples   apple   NOUN   NNS      dobj   xxxx      True    False                                      (Number=Plur)       True
# 4          ,       ,  PUNCT     ,     punct      ,     False    False                                   (PunctType=Comm)      False
# 5        but     but  CCONJ    CC        cc    xxx      True     True                                     (ConjType=Cmp)      False
# 6         he      he   PRON   PRP     nsubj     xx      True     True  (Case=Nom, Gender=Masc, Number=Sing, Person=3,...      False
# 7       gave    give   VERB   VBD      conj   xxxx      True    False                         (Tense=Past, VerbForm=Fin)      False
# 8          2       2    NUM    CD      dobj      d     False    False                                     (NumType=Card)      False
# 9         to      to    ADP    IN      prep     xx      True     True                                                 ()      False
# 10       his     his   PRON  PRP$      poss    xxx      True     True  (Gender=Masc, Number=Sing, Person=3, Poss=Yes,...      False
# 11    friend  friend   NOUN    NN      pobj   xxxx      True    False                                      (Number=Sing)      False
# 12         .       .  PUNCT     .     punct      .     False    False                                   (PunctType=Peri)      False
# 13       The     the    DET    DT       det    Xxx      True     True                       (Definite=Def, PronType=Art)      False
# 14     event   event   NOUN    NN     nsubj   xxxx      True    False                                      (Number=Sing)      False
# 15      will    will    AUX    MD       aux   xxxx      True     True                                     (VerbForm=Fin)      False
# 16     start   start   VERB    VB      ROOT   xxxx      True    False                                     (VerbForm=Inf)      False
# 17        at      at    ADP    IN      prep     xx      True     True                                                 ()      False
# 18      7:30    7:30    NUM    CD    nummod   d:dd     False    False                                     (NumType=Card)      False
# 19        PM      PM  PROPN   NNP      pobj     XX      True    False                                      (Number=Sing)      False
# 20         ,       ,  PUNCT     ,     punct      ,     False    False                                   (PunctType=Comm)      False
# 21       and     and  CCONJ    CC        cc    xxx      True     True                                     (ConjType=Cmp)      False
# 22        we      we   PRON   PRP     nsubj     xx      True     True    (Case=Nom, Number=Plur, Person=1, PronType=Prs)       True
# 23    expect  expect   VERB   VBP      conj   xxxx      True    False                         (Tense=Pres, VerbForm=Fin)      False
# 24    around  around    ADP    IN    advmod   xxxx      True     True                                                 ()      False
# 25       100     100    NUM    CD    nummod    ddd     False    False                                     (NumType=Card)      False
# 26    guests   guest   NOUN   NNS      dobj   xxxx      True    False                                      (Number=Plur)       True
# 27         .       .  PUNCT     .     punct      .     False    False                                   (PunctType=Peri)      False
# 28         I       I   PRON   PRP     nsubj      X      True     True    (Case=Nom, Number=Sing, Person=1, PronType=Prs)      False
# 29      have    have    AUX   VBP       aux   xxxx      True     True               (Mood=Ind, Tense=Pres, VerbForm=Fin)      False
# 30      read    read   VERB   VBN      ROOT   xxxx      True    False           (Aspect=Perf, Tense=Past, VerbForm=Part)      False
# 31         3       3    NUM    CD    nummod      d     False    False                                     (NumType=Card)      False
# 32     books    book   NOUN   NNS      dobj   xxxx      True    False                                      (Number=Plur)       True
# 33      this    this    DET    DT       det   xxxx      True     True                        (Number=Sing, PronType=Dem)      False
# 34     month   month   NOUN    NN  npadvmod   xxxx      True    False                                      (Number=Sing)      False
# 35         ,       ,  PUNCT     ,     punct      ,     False    False                                   (PunctType=Comm)      False
# 36       and     and  CCONJ    CC        cc    xxx      True     True                                     (ConjType=Cmp)      False
# 37         I       I   PRON   PRP     nsubj      X      True     True    (Case=Nom, Number=Sing, Person=1, PronType=Prs)      False
# 38        'm      be    AUX   VBP       aux     'x     False     True  (Mood=Ind, Number=Sing, Person=1, Tense=Pres, ...      False
# 39  planning    plan   VERB   VBG      conj   xxxx      True    False           (Aspect=Prog, Tense=Pres, VerbForm=Part)      False
# 40        to      to   PART    TO       aux     xx      True     True                                                 ()      False
# 41      read    read   VERB    VB     xcomp   xxxx      True    False                                     (VerbForm=Inf)      False
# 42         2       2    NUM    CD      dobj      d     False    False                                     (NumType=Card)      False
# 43      more    more    ADJ   JJR      amod   xxxx      True     True                                       (Degree=Cmp)      False
# 44    before  before    ADP    IN      prep   xxxx      True     True                                                 ()      False
# 45       the     the    DET    DT       det    xxx      True     True                       (Definite=Def, PronType=Art)      False
# 46       end     end   NOUN    NN      pobj    xxx      True    False                                      (Number=Sing)      False
# 47        of      of    ADP    IN      prep     xx      True     True                                                 ()      False
# 48       the     the    DET    DT       det    xxx      True     True                       (Definite=Def, PronType=Art)      False
# 49      week    week   NOUN    NN      pobj   xxxx      True    False                                      (Number=Sing)      False
# 50         .       .  PUNCT     .     punct      .     False    False                                   (PunctType=Peri)      False
